# %% [markdown]
# # Slot 1 Introduction to Python
#
# ## Task 1
# Print 'Hello World'

# %%
print('Hello, World!')
# Out:
# Hello, World!

# %% [markdown]
# ## Task 2
#
# Calculate 3*4

# %% [markdown]
# ### Task 3
#
# Assign variable using '='.
#
# a = 10
#
# b = 20
#
# Write code to

# %%
a =10
b = 20
c = a + b
print(c)
# Out:
# 30
