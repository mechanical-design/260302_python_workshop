# %% [markdown]
# ## Slot 1 Introduction to Python

# %% [markdown]
# ### Task 1
# Show text and number
# Print `Hello World`

# %%
print('Hello, World!')
# Out:
# Hello, World!

# %% [markdown]
# ### Task 2
#
# Print no `123456`

# %%
print(123456)
# Out:
# 123456

# %% [markdown]
# ### Task 3
#
# Combine word 'FKM' dan 'Hijau'

# %%
print('FKM'+' Hijau')
# Out:
# FKM Hijau

# %% [markdown]
# ### Task 4
#
# Calculate 3*4

# %%
3*4
# Out:
# 12

# %% [markdown]
# ### Task 5
#
# Do calculation `22x4` inside print()

# %%
2/3
# Out:
# 0.6666666666666666

# %% [markdown]
# ### Task 6
#
# Assign variable using '='.
#
# a = 10
#
# b = 20
#
# Write code to

# %%
2+1/4+1/4
# Out:
# 2.5

# %% [markdown]
# #### Task 7
#
# Assign variable and print type

# %%
print(22*4)
# Out:
# 88

# %% [markdown]
# #### Task 8
#
# Assign variable and print value

# %%
a =10
b = 20
c = a + b
print(c)
# Out:
# 30

# %% [markdown]
# #### Task 9
#
# Given pressure = 250 MPa
#
# Show in output word `Pressure = 250 Mpa`

# %%
pressure = 250
print('Pressure=', pressure, 'MPa')
# Out:
# Pressure= 250 MPa

# %% [markdown]
# #### Task 10
#
# Copy the code below;
#
# ```
# print('A')
# print('B')
# print('C')
# ```
# Using comment `#` to hide ` print('B')` so the output will be;
#
# ```
# A
# C
# ```

# %%
print('A')
#print('B')
print('C')
# Out:
# A
# C

# %% [markdown]
# #### Task 11
#
# Use `if-statements` to check the variable `age = 10`
#
# (Use if age more than 18 `Eligible to vote` or else `Not eligible to vote`)

# %%
age = 10
if age >= 18:
   print("Eligible to vote.")
else:
   print("Not eligible to vote.")
# Out:
# Not eligible to vote.
